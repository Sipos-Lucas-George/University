# %%
t = var('t')
x = function('x')(t)
eqd = diff(x,t,2)+x==0
desolve(eqd, x, ics=[0,1,0])
# Out:
# cos(t)

# %%
t = var('t')
x = function('x')(t)
eqd = diff(x,t,2)+x==0
desolve(eqd, x)
# Out:
# _K2*cos(t) + _K1*sin(t)

# %%
show(desolve(eqd, x))
# Out:
# _K2*cos(t) + _K1*sin(t)

# %%
t = var('t')
x = function('x')(t)
eqd = diff(x,t,2)+x==1
desolve(eqd, x, ics=[0,0,pi,0])
# Out:
# []

# %%
t = var('t')
x = function('x')(t)
eqd = diff(x,t)==x^2-1
u = var('u')
show(plot(u^2-1, [u,-10,10]))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graphics object consisting of 1 graphics primitive
